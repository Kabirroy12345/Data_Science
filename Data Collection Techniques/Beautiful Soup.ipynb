# %% [markdown]
# 1. What is BeautifulSoup?
# BeautifulSoup is a Python library used to parse HTML and XML documents.
# It creates a parse tree from page content, making it easy to extract data.
# It is often used with requests to scrape websites.

# %%
pip install beautifulsoup4 lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\onedrive\annaconda\lib\site-packages (4.13.5)
# Requirement already satisfied: lxml in c:\users\hp\onedrive\annaconda\lib\site-packages (5.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\onedrive\annaconda\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\onedrive\annaconda\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
