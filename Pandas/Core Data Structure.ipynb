# %%
import pandas as pd

# %% [raw]
# #Series are like list with labels

# %%
s1=pd.Series([71,84,56,98,33])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)  #Auto indexing
# Out:
# 0    71
# 1    84
# 2    56
# 3    98
# 4    33
# dtype: int64

# %%
s2=pd.Series([71,84,56,98,33],index=["Aritra","Anshumaan","Niya","Kabir","Ayan"])

# %%
print(s2)
# Out:
# Aritra       71
# Anshumaan    84
# Niya         56
# Kabir        98
# Ayan         33
# dtype: int64

# %%
s2.Kabir
# Out:
# np.int64(98)

# %%
s2.Anshumaan
# Out:
# np.int64(84)

# %%
# A pandas.Series may look similar to a Python dictionary because both store data
# with labels, but a Series offers much more. Unlike a dictionary, a Series supports
# fast vectorized operations, automatic index alignment during arithmetic, and
# handles missing data using NaN . It also allows both label-based and positionbased access, and integrates seamlessly with the pandas ecosystem, especially
# DataFrames. While a dictionary is great for simple key–value storage, a Series is
# better suited for data analysis and manipulation tasks where performance,
# flexibility, and built-in functionality matter.

# %% [markdown]
# ##DataFrame is like a Dictionary of Series

# %%
data={
    "name":["Kabir","Anshumaan","Aritra"],
    "age":[11,22,33],
    "city":["Delhi","Chennai","Agra"]
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#         name  age     city
# 0      Kabir   11    Delhi
# 1  Anshumaan   22  Chennai
# 2     Aritra   33     Agra

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
